# %% [markdown]
# # The Battle of Neighbourhoods – The Best Place to Open a Chinese Restaurant

# %% [markdown]
# ## <b>Introduction</b>:
#
# Toronto has the second-highest percentage of constant foreign-born population among world cities after Miami, Florida. Its diversity can be proven in the ethnic neighbourhoods, like Chinatown, Corso Italia, Greektown and etc. Chinese is reported to be one of the most common ethnic origins who live in Toronto, and thus that would be a huge potential in launching a Chinese restaurant.
#
# This project is aimed to help those entrepreneurs to identifying which neighbourhood in Toronto is the best neighbourhood to have a Chinese restaurant.

# %% [markdown]
# ## Target Audience:
# The target audience of this report would be focused on the category whose are interested in having a Chinese restaurant business or to grow their business. This report will provide them some useful information that can be applied as a reference or a suggestion.

# %% [markdown]
# ## Data Overview:
#
# The required data in this report are a number of different online sources, such as the Wikipedia page that would providing a list of neighbourhoods in Toronto, the geographical location of Toronto in order to retrieving the longitude and latitude information( http://cocl.us/Geospatial_data) and lastly, the venue data information through Foursquare to define information of interest and to explore the best neighbourhood to open a chinese restaurant.
#
# ![image.png](attachment:1996bee7-5235-4572-bb42-a7dcd3f4ea38.png)
# ### 1.1  Wikipedia page (https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M)
#
#     The wikipedia page has all required information to explore the Toronto neighbourhood. In order to retrieve the table from the wikipedia page and to transform it into a pandas dataframe, data scraping has been applied.
#    ![image.png](attachment:1bbd50cb-558c-4048-9536-5bbabc68513f.png)
#
#     To better visualize the amount of neighbourhoods within a borough, these data have been transform into a plot table. From this table, North York is the borough which has the most neighbourhood.
#
#    ![image.png](attachment:aa294cc3-f013-40a2-b1f1-8381167951a5.png)
# ### 1.2  geographical location
#
#     Since the source is in csv formaat, pandas dataframe has been applied to extract its information. With this source, latitude and longitude information can be retrieved along with the postal code respectively.
#
# ![image.png](attachment:175d698a-5aaf-4686-8224-4e2ee8d2a9c8.png)
#
# ### 1.3  Venue Data with Foursquare
#
#     These data is being grouped by their neighbourhood.
# ![image.png](attachment:a35c522f-db15-46f6-8672-182634b2b00b.png)
#
#
#     In order to better look for keywords that related to Chinese restaurant from venue categories, unique() has been applied.
#    ![image.png](attachment:443b2e9f-fc4a-4caf-8e11-5b4c5592e93c.png)
#
#     From these keywords from venue categories, we pick up all the Chinese cuisine related keyword and initialize them as a array list.
#    ![image.png](attachment:082b6ef7-d315-4f40-a610-f6889614d1cf.png)

# %% [markdown]
# ## Discussion:
#
# This project is intended to find out a best place for those who are interested to have Chinese cuisine related restaurant in Toronto. From this project, we also manages to find out which borough is having the most neighbourhood. In order to avoid missing any chinese cuisine ralated restaurant, unique()has been applied within the venue category. With the keywords we obtained through the unique(), we were able to anaylze each neighbourhoods and their rates of having Chinese cuisine related restaurant. And thus, it helps to identify where is the best borough and neighbourhood to own a Chinese restaurant business.
#
# After all the findings, we finally found that the neighbourhoods: Clarks Corner, Tam O'Shanter and Sullivan where they located within Scarborough is the best place to own a Chinese cuisine restaurant.
#
# ![image.png](attachment:41687aee-40c9-4a02-8d01-5bd7a46b858c.png)
#
# And the most perfect location is located at:
#
# ![image.png](attachment:71219edb-9d7c-4ff6-8512-d591d8c1fd2b.png)
#
# ![image.png](attachment:ebd07c07-33b6-4935-afe9-87be11fd0557.png)

# %% [markdown]
# ## Conclusion:
#
# In conclusion, this project could be utilized as a recomendation for those who are interested to own a Chinese cuisine related business in Toronto.
#
# Aside from those who are interested Chinese cuisine restaurant, those who are interested to have other business also can utilize this report by modifying the venue categories and the unique() command into the venue data.
